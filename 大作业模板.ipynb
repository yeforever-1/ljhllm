# %% [markdown]
# # 大作业标题： 基于深度学习的图像识别系统：猫狗分类项目

# %% [markdown]
# 一、项目背景与目的
#
# 背景：
# 图像识别在人工智能领域的重要性
# 图像识别是人工智能领域的一个重要分支，它涉及到计算机视觉技术，使计算机能够从图像中识别和理解视觉信息。以下是图像识别在人工智能领域的重要性
#
# 自动化和效率升：
#
# 图像识别技术可以自动化许多需要人工视觉的任务，如质量控制、监控和安全检查，从而提高效率和减少成本。
# 增人机交互：
#
# 图像识别使得机器能够更好地理解和响应人类的手势、表情和视觉提示，改善人机交互体验
# 安全和监控：
#
# 在安全领域，图像识别技术被用于面部识别、行为分析和异常检测，以提高公共和个人全。
# 医疗影像分析：
#
# 在医疗领域，图像识别技术可以帮助医生分析X光片、MRI和CT扫描，辅诊断疾病。
# 自动驾驶技术：
#
# 自动驾驶汽车依赖于图像识别技术来识别道路标志、行人、其他辆和交通信号。
# 零售和市场分析：
#
# 在零售业，图像识别可以用于顾客行为分析、货架监控和库存管理
# 增强现实（AR）和虚拟现实（VR）：
#
# 图像识别技术是AR和VR的关键技术，用于环境理解和交互。
# 科学研究：
#
# 在天文学、生物学和地质学等领域
# ，图像识别技术帮助科学家分析和解释复杂的图像数据。
# 猫狗分类问题的实际应用场景
# 猫狗分类问题是一个经典的图像识别问题，通常作深度学习模型训的入门示例。以下是一些实际应用场景：
#
# 宠物识别应用：
#
# 开发宠物识别应用程序帮助宠物主人通过上传照片来识别他们的宠物种类。
# 动物保护组织：
#
# 动物保护组织可以使用猫狗分类术来帮助识别和分类救助的动物，以便更好地安置和照顾它们。
# 宠物保险：
#
# 物保险公司可以利用图像识别技术来验证保险索赔中的宠物身份。
# 智能家居系统：
#
# 在智能家居系统中，图像识别可以帮助别家中的宠物，以便于监控宠物的活动或控制宠物相关的智能家居设备。
# 宠物健康监测：
#
# 结合图像识别技术，可开发出监测宠物健康状况的应用，如通过分析宠物的体态和行为来检测健康问题。
# 教育和研究：
#
# 在教育领，猫狗分类问题可以作为教学案例，帮助学生理解机器学习和图像识别的基本概念。帮助快速检辨别猫狗索和管理图像资料。
# 介绍图像识别在人工智能领域的重要性。
# 阐述猫狗分类问题的实际应用场景。
# 目的：
#
# 培养学生对图像处理和机器学习的基本理解。
# 训练学生使用深度学习模型解决实际问题的能力。
# 提高学生的数据预处理、模型构建、评估和优化的技能。

# %% [markdown]
# 二、数据预处理
#
# 数据集描述：数据集丰富，覆盖多
#
# 介绍所使用的猫狗图像数据集的来源和特点。
# 预处理步骤：
# 数据清洗：
#
# 移除或修正数据集中的错误、重复或不完整的数据。
# 数据标准化/归化：
#
# 将数据缩放到一个特定的范围，通常是[0, 1]或[-1, 1]，或者进行Z-score标准化（均值为0，标准差为1）。
# 数据增强：
#
# 对图像数据，可以通过旋转、缩放、裁剪、颜色变换等方法增加数据的多样性，减少过拟。
# 类型转换：
#
# 将数据转换为适合模型输入的格式，例如，将图像从PIL图像转换为PyTorh张量。
# 数据编码：
#
# 对分类变量进行编码，如使用独热编码（One-Hot Encoding）或标签编码（Label Encding）。
# 分割数据集：
#
# 将数据集分为训练集、验证集和测试集。
# 批量处理（atch Processing）：
#
# 将数据分成小批量（batches），以便于模型训练的内存管理和加速计算。
# 数据维度调整：
#
# 对于图像数据，可能需要调整图像尺寸以匹配模型输入层的期望尺寸。
# 数据加载：
#
# 使用数据加载器（如PyTorch的DataLoaer）来异步加载数据，提高训练效率。
# 去除异常值：
#
# 识别并处理数据中的异常值，这些值可能会对模型训练产生负面影响。
#
# 图像尺寸调整：统一图像尺寸以适应模型输入。
# 归一化处理：将像素值缩放到一定范围，如0到1。
# 数据增强：通过旋转、翻转、缩放等方法增加数据多样性。
# 划分数据集：将数据集分为训练集、验证集和测试集。

# %% [markdown]
# 三、模型构建
#
# 模型选择：CNN
# 理论基础
# 局部感受野：CNN通过局部感受野捕捉图像的局部特征。这意味着每个卷积核只关注图像的一个局部区域，这与人类视觉系统的工作方式相似
#
# 权重共享：在传统神经网络中，每个输入与输出之间的连接都有独立的权重。而在CNN中，卷积核的权重在整个输入数据上共享，这大大减少了模型的参数量。
#
# 平移不变性：由于权重共享，CNN能够学习到具有平移不变性的特征，即相同的特征检测器可以在输入的不同位置检测到相的特征。
#
# 层次结构：CNN通过多个卷积层堆叠形成，每一层都在前一层提取的特征基础上进一步提取更高级的特征，形成特的层次结构。
#
# 池化（Pooling）：通常跟在卷积层之后，用于降低特征的空间维度，减少计算量，并提供一定度的过拟合控制。
#
# 全连接层（Fully Connected Layer）：在多个卷积和池化层之后，CNN通常会有一到多个全连接层，用于将特征映射到最终的输出。
# 描述所选择的深度学习模型（如CNN）及其理输入层（Input Layer）：接收原始数据输入，例如图像。
#
# 卷积层（Convolutional Layer）：包含多个卷积核（或滤波器），每个卷积核负责提取输入数据中的特定特。
#
# 激活函数（Activation Function）：通常使用ReLU（Rectified Linear Unit），它可以帮助解决梯度消失问题，并加训练。
#
# 池化层（Pooling Layer）：常用的池化方法有最大池化（Max Pooling）和平均池化（Average Pooling），用于降低特征维度和制过拟合。
#
# 归一化层（Normalization Layer）：可选，例如批量归一化（Batch Normalization），用于提高练速度和性能。
#
# 全连接层（Fully Connected Layer）：将卷积层和池化层提取的特映射到最终的输出。
#
# 输出层（Output Layer）：根据任务的不同，输出层可以是Softmax层用于分类任务）或其他。
#
# 损失函数（Loss Function）：根据任务类型选择合适的损失函数，例如交叉熵损失（Cross-Entropy Loss）用于分类任务。论基础。
# 模型架构：
#
# 详细说明模型的层结构，包括卷积层、池化层、全连接层等。
# 描述激活函数、损失函数和优化器的选择。

# %% [markdown]
# 四、模型评估
#
# 评估指标：
# 1.准确率（Accuracy）
# 准确率是最直观的性能指标，它表示模型预测正确的样本占总样本的比例）：模型正确预测为负类的样本数。
# 2. 召回率（Recall）
# 召回率，也称为真正率或灵敏度，表示模型成功识别e Negative, FN）：模型错预测为负类的正类样本数。
# 召回率关注的是模型对正类的识别能力。
#
# 3. 精确率（Pr
# ​
#
#
# 假正例（FalsePositive, FP）：模型错误预测为正类的负类样本数。
# 精确率关注的是模型预测正类的准确性。
#
# 4
# =
# 2
# ×
# 精确率
# ×
# 召回率
# 精确率
# +
# 召回率
# F1分数=2×
# 精确率+召回率
# 精确率×召回率
# ​
#
#
# F1分数特别适用于那些正负样本不平衡的情况。
# 精确率
# +
# 召回率
# F1分数=2×
# 精确率+召回率
# 精确率×召回率
# ​
#
#
# F1分数特别适用于那些正负样本不平衡的情况。
# 准确率、召回率、F1分数等性能指标的介绍。
# 评估方法：
#
# 交叉验证：确保模型的泛化能力。
# 混淆矩阵：直观展示分类结果。

# %% [markdown]
# 五、结果分析与优化
#
# 结果分析：
# 误差还是存在，但大体不会出错
# 对比不同模型的性能，分析其优缺点。
# 讨论模型在特定类别上的表现差异。
# 模型优化：
# 根据分析结果调整模型参数。
# 尝试不同的网络结构或正则化技术以提高性能。

# %% [markdown]
# 附录
#
# github项目链接（含代码、数据）
# 附带仓库目录结构截图
#
# https://github.com/yeforever-1/ljhllm/blob/main/dazuoye.ipynb

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# 读取图片
img = mpimg.imread('C:\\Users\81076\Desktop\实训11111\捕获1.PNG')

# 显示图片
plt.imshow(img)
plt.show()

# %%
N = 2
label_dict = {"cats": 0, "dogs": 1}
class_dict = {0: "cats", 1: "dogs"}

# %%
import copy
import os
import random

import numpy as np
import torch
import torch.nn as nn
from torch import optim
from tqdm import tqdm

from classify.data_process import load_data
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter

from classify.decorator import metric_time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


def setup_seed(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True


setup_seed(20)


class cnn(nn.Module):
    def __init__(self, in_channels=3):
        super(cnn, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(
                in_channels=in_channels,
                out_channels=16,
                kernel_size=3,
                stride=2,
            ),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
        )

        self.conv2 = nn.Sequential(
            nn.Conv2d(
                in_channels=16,
                out_channels=32,
                kernel_size=3,
                stride=2,
            ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
        )

        self.conv3 = nn.Sequential(
            nn.Conv2d(
                in_channels=32,
                out_channels=64,
                kernel_size=3,
                stride=2,
            ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
        )
        self.fc1 = nn.Linear(3 * 3 * 64, 64)
        self.fc2 = nn.Linear(64, 10)
        self.relu = nn.ReLU()
        self.softmax = nn.Softmax()
        self.out = nn.Linear(10, N)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = x.view(x.shape[0], -1)
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.softmax(self.out(x))
        x = F.log_softmax(x, dim=1)
        return x


def get_val_loss(model, Val):
    model.eval()
    criterion = nn.CrossEntropyLoss().to(device)
    val_loss = []
    for (data, target) in Val:
        data, target = data.to(device), target.long().to(device)
        output = model(data)
        loss = criterion(output, target)
        val_loss.append(loss.cpu().item())

    return np.mean(val_loss)


@metric_time
def train():
    writer = SummaryWriter("log/")
    train_data_loader, val_data_loader, _ = load_data()
    print('train...')
    epoch_num = 30
    best_model = None
    min_epochs = 5
    min_val_loss = 5
    model = cnn().to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.0008)
    criterion = nn.CrossEntropyLoss().to(device)
    for epoch in tqdm(range(epoch_num), ascii=True):
        train_loss = []
        for batch_idx, (data, target) in enumerate(train_data_loader):
            data, target = data.to(device), target.long().to(device)
            model.train()
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            train_loss.append(loss.cpu().item())
        # validation
        val_loss = get_val_loss(model, val_data_loader)
        writer.add_scalar("val_loss", val_loss, epoch)
        if epoch + 1 > min_epochs and val_loss < min_val_loss:
            min_val_loss = val_loss
            best_model = copy.deepcopy(model)

        tqdm.write('Epoch {:03d} train_loss {:.5f} val_loss {:.5f}'.format(epoch, np.mean(train_loss), val_loss))

    torch.save(best_model.state_dict(), "model/cnn.pkl")


@metric_time
def test():
    _, _, test_dataset = load_data()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = cnn().to(device)
    model.load_state_dict(torch.load("model/cnn.pkl"), False)
    total = 0
    current = 0
    model.eval()
    for (data, target) in test_dataset:
        data, target = data.to(device), target.to(device)
        outputs = model(data)
        predicted = torch.max(outputs.data, 1)[1].data
        total += target.size(0)
        current += (predicted == target).sum()

    print('Accuracy:%d%%' % (100 * current / total))

# %%
train()

# %%
test()

# %%
from PIL import Image
from matplotlib import pyplot as plt
from torchvision import transforms

# %%
model = cnn().to(device)
model.load_state_dict(torch.load("model/cnn.pkl"), False)
model.eval()

_img_path = "data/testing_data/cats/cat.1005.jpg"

transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))  # normalization
])
img = Image.open(_img_path).convert('RGB')
# 模拟批样本
img_transform = transform(img).unsqueeze(0)

output = model(img_transform)
pred = class_dict[torch.max(output.data, 1)[1].data.item()]
print(pred)

# %%
plt.imshow(img, cmap='gray')
plt.show()
